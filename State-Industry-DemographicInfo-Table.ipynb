# %%
# Imports
import uuid
from confluent_kafka.admin import AdminClient, NewTopic
from pyspark.sql.functions import col
from pyspark.sql.functions import lit
from pyspark.sql.types import FloatType
from pyspark.sql.types import StringType
from pyspark.sql import Row
import pandas as pd

# %%
storageAccount = "gen10datafund2207"
storageContainer = "group-2-capstone"
clientSecret = "Cty8Q~AvEO_qC-MjvPvosYauiNsffOHKnMpj7cmd"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/adambrew/ABS"


configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

try: 
    dbutils.fs.unmount(mount_point)
except:
    pass

dbutils.fs.mount(
source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
mount_point = mount_point,
extra_configs = configs)

database = "group-2-capstone"
user = "group_2"
password  = 'Sp0ngeB0b'
server = "gen10-data-fundamentals-22-07-sql-server.database.windows.net"
port = "1433"
# Out:
# /mnt/adambrew/ABS has been unmounted.
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
display(dbutils.fs.ls('/mnt/adambrew/ABS'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
ABS_df = spark.read.format("csv").load("/mnt/adambrew/ABS/Cleaned_ABS_Company_Summary.csv", header=True, inferSchema='True')
display(ABS_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# # State Table

# %%
State_df = ABS_df[["State"]].distinct().sort(col("State"))
State_df = State_df.withColumn("StateAcronym", col("State"))
State_df_pd = State_df.toPandas()
State_df_pd["StateAcronym"] = State_df_pd["StateAcronym"].apply(lambda x : us_state_to_abbrev[x])
State_df_pd = State_df_pd[State_df_pd["StateAcronym"] != "DC"]
State_df_pd["StateName"] = State_df_pd["State"]
State_df_pd = State_df_pd.drop("State", axis = 1)
#State_df_pd["StateID"] = State_df_pd.index + 1
State_df = spark.createDataFrame(State_df_pd)
State_df = State_df.select("StateName", "StateAcronym")
new_row = spark.createDataFrame([("Unanswered", "Unanswered")], State_df.columns)
State_df = State_df.union(new_row)
display(State_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Make su
# Save to Database
database = "group-2-capstone"
user = "group_2"
password  = "Sp0ngeB0b"
server = "gen10-data-fundamentals-22-07-sql-server.database.windows.net"

# Helper function: write in table
def saveToTable(df, table, change='append'):
    df.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
                .mode(change) \
                .option("dbtable", table) \
                .option("user", user) \
                .option("password", password) \
                .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
                .save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# writing dataframe to ddatabase
saveToTable(State_df, "dbo.State", change = "append")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# # Industry Table

# %%
len("Administrative and Support and Waste Management and Remediation Services")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
Industry_df = ABS_df[["Industry"]].distinct().sort(col("Industry"))
Industry_df = Industry_df.withColumn("IndustryName", col("Industry"))
Industry_df = Industry_df.drop("Industry")
# new_row = spark.createDataFrame([("Unanswered")], Industry_df.columns)
# Industry_df = Industry_df.union(new_row)
# display(Industry_df)
collection = Industry_df.collect()
collection.append({"IndustryName" : 'Unanswered'})
Industry_df = spark.createDataFrame(collection)
display(Industry_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# writing dataframe to ddatabase
saveToTable(Industry_df, "dbo.Industry", change = "append")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# # DemographicInfo Table

# %%
Demographic_df = ABS_df[["Race", "Ethnicity", "Sex"]].distinct().sort(col("Race"),col("Ethnicity"), col("Sex"))
display(Demographic_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Race</th><th>Ethnicity</th><th>Sex</th></tr></thead><tbody><tr><td>American Indian and Alaska Native</td><td>Hispanic</td><td>Female</td></tr><tr><td>American Indian and Alaska Native</td><td>Hispanic</td><td>Male</td></tr><tr><td>American Indian and Alaska Native</td><td>Non-Hispanic</td><td>Female</td></tr><tr><td>American Indian and Alaska Native</td><td>Non-Hispanic</td><td>Male</td></tr><tr><td>Asian</td><td>Hispanic</td><td>Female</td></tr><tr><td>Asian</td><td>Hispanic</td><td>Male</td></tr><tr><td>Asian</td><td>Non-Hispanic</td><td>Female</td></tr><tr><td>Asian</td><td>Non-Hispanic</td><td>Male</td></tr><tr><td>Black or African American</td><td>Hispanic</td><td>Female</td></tr><tr><td>Black or African American</td><td>Hispanic</td><td>Male</td></tr><tr><td>Black or African American</td><td>Non-Hispanic</td><td>Female</td></tr><tr><td>Black or African American</td><td>Non-Hispanic</td><td>Male</td></tr><tr><td>Native Hawaiian and Other Pacific Islander</td><td>Hispanic</td><td>Female</td></tr><tr><td>Native Hawaiian and Other Pacific Islander</td><td>Hispanic</td><td>Male</td></tr><tr><td>Native Hawaiian and Other Pacific Islander</td><td>Non-Hispanic</td><td>Female</td></tr><tr><td>Native Hawaiian and Other Pacific Islander</td><td>Non-Hispanic</td><td>Male</td></tr><tr><td>White</td><td>Hispanic</td><td>Female</td></tr><tr><td>White</td><td>Hispanic</td><td>Male</td></tr><tr><td>White</td><td>Non-Hispanic</td><td>Female</td></tr><tr><td>White</td><td>Non-Hispanic</td><td>Male</td></tr></tbody></table></div>

# %%
df_list_of_dict = [row.asDict() for row in Demographic_df.collect()]


cols = list(df_list_of_dict[0].keys())
num_cols = len(cols)
num_rows = len(df_list_of_dict)

for i in range(num_cols):
    copy_l = [row.asDict() for row in Demographic_df.collect()]
    for j in range(num_rows):
        copy_l[j][cols[i]] = 'Unanswered'
    for k in copy_l:
        df_list_of_dict.append(k)
        
df_list_of_dict = [dict(t) for t in {tuple(d.items()) for d in df_list_of_dict}]
df_list_of_dict
# Out:
# Out[73]: [{'Race': 'Asian', 'Ethnicity': 'Unanswered', 'Sex': 'Female'},
#  {'Race': 'Asian', 'Ethnicity': 'Hispanic', 'Sex': 'Female'},
#  {'Race': 'Asian', 'Ethnicity': 'Non-Hispanic', 'Sex': 'Female'},
#  {'Race': 'Black or African American', 'Ethnicity': 'Hispanic', 'Sex': 'Male'},
#  {'Race': 'American Indian and Alaska Native',
#   'Ethnicity': 'Unanswered',
#   'Sex': 'Female'},
#  {'Race': 'American Indian and Alaska Native',
#   'Ethnicity': 'Hispanic',
#   'Sex': 'Female'},
#  {'Race': 'Black or African American',
#   'Ethnicity': 'Non-Hispanic',
#   'Sex': 'Male'},
#  {'Race': 'Native Hawaiian and Other Pacific Islander',
#   'Ethnicity': 'Hispanic',
#   'Sex': 'Male'},
#  {'Race': 'White', 'Ethnicity': 'Hispanic', 'Sex': 'Female'},
#  {'Race': 'White', 'Ethnicity': 'Non-Hispanic', 'Sex': 'Female'},
#  {'Race': 'Native Hawaiian and Other Pacific Islander',
#   'Ethnicity': 'Non-Hispanic',
#   'Sex': 'Male'},
#  {'Race': 'Unanswered', 'Ethnicity': 'Hispanic', 'Sex': 'Female'},
#  {'Race': 'Unanswered', 'Ethnicity': 'Non-Hispanic', 'Sex': 'Female'},
#  {'Race': 'American Indian and Alaska Native',
#   'Ethnicity': 'Non-Hispanic',
#   'Sex': 'Female'},
#  {'Race': 'White', 'Ethnicity': 'Unanswered', 'Sex': 'Male'},
#  {'Race': 'Asian', 'Ethnicity': 'Unanswered', 'Sex': 'Male'},
#  {'Race': 'Asian', 'Ethnicity': 'Hispanic', 'Sex': 'Male'},
#  {'Race': 'Asian', 'Ethnicity': 'Non-Hispanic', 'Sex': 'Male'},
#  {'Race': 'American Indian and Alaska Native',
#   'Ethnicity': 'Unanswered',
#   'Sex': 'Male'},
#  {'Race': 'American Indian and Alaska Native',
#   'Ethnicity': 'Hispanic',
#   'Sex': 'Male'},
#  {'Race': 'White', 'Ethnicity': 'Hispanic', 'Sex': 'Male'},
#  {'Race': 'White', 'Ethnicity': 'Non-Hispanic', 'Sex': 'Male'},
#  {'Race': 'Black or African American',
#   'Ethnicity': 'Hispanic',
#   'Sex': 'Unanswered'},
#  {'Race': 'Unanswered', 'Ethnicity': 'Hispanic', 'Sex': 'Male'},
#  {'Race': 'Native Hawaiian and Other Pacific Islander',
#   'Ethnicity': 'Hispanic',
#   'Sex': 'Unanswered'},
#  {'Race': 'Native Hawaiian and Other Pacific Islander',
#   'Ethnicity': 'Non-Hispanic',
#   'Sex': 'Unanswered'},
#  {'Race': 'Black or African American',
#   'Ethnicity': 'Non-Hispanic',
#   'Sex': 'Unanswered'},
#  {'Race': 'Unanswered', 'Ethnicity': 'Non-Hispanic', 'Sex': 'Male'},
#  {'Race': 'American Indian and Alaska Native',
#   'Ethnicity': 'Non-Hispanic',
#   'Sex': 'Male'},
#  {'Race': 'Black or African American',
#   'Ethnicity': 'Unanswered',
#   'Sex': 'Female'},
#  {'Race': 'Native Hawaiian and Other Pacific Islander',
#   'Ethnicity': 'Unanswered',
#   'Sex': 'Female'},
#  {'Race': 'Asian', 'Ethnicity': 'Hispanic', 'Sex': 'Unanswered'},
#  {'Race': 'Asian', 'Ethnicity': 'Non-Hispanic', 'Sex': 'Unanswered'},
#  {'Race': 'American Indian and Alaska Native',
#   'Ethnicity': 'Hispanic',
#   'Sex': 'Unanswered'},
#  {'Race': 'White', 'Ethnicity': 'Hispanic', 'Sex': 'Unanswered'},
#  {'Race': 'Black or African American',
#   'Ethnicity': 'Hispanic',
#   'Sex': 'Female'},
#  {'Race': 'Black or African American',
#   'Ethnicity': 'Non-Hispanic',
#   'Sex': 'Female'},
#  {'Race': 'Native Hawaiian and Other Pacific Islander',
#   'Ethnicity': 'Hispanic',
#   'Sex': 'Female'},
#  {'Race': 'Native Hawaiian and Other Pacific Islander',
#   'Ethnicity': 'Non-Hispanic',
#   'Sex': 'Female'},
#  {'Race': 'White', 'Ethnicity': 'Non-Hispanic', 'Sex': 'Unanswered'},
#  {'Race': 'Black or African American',
#   'Ethnicity': 'Unanswered',
#   'Sex': 'Male'},
#  {'Race': 'White', 'Ethnicity': 'Unanswered', 'Sex': 'Female'},
#  {'Race': 'Native Hawaiian and Other Pacific Islander',
#   'Ethnicity': 'Unanswered',
#   'Sex': 'Male'},
#  {'Race': 'American Indian and Alaska Native',
#   'Ethnicity': 'Non-Hispanic',
#   'Sex': 'Unanswered'}]

# %%
Demographic_df = spark.createDataFrame(df_list_of_dict)
Demographic_df = Demographic_df.distinct()
display(Demographic_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Ethnicity</th><th>Race</th><th>Sex</th></tr></thead><tbody><tr><td>Unanswered</td><td>American Indian and Alaska Native</td><td>Female</td></tr><tr><td>Unanswered</td><td>Asian</td><td>Female</td></tr><tr><td>Hispanic</td><td>Black or African American</td><td>Male</td></tr><tr><td>Hispanic</td><td>Asian</td><td>Female</td></tr><tr><td>Non-Hispanic</td><td>Asian</td><td>Female</td></tr><tr><td>Non-Hispanic</td><td>Native Hawaiian and Other Pacific Islander</td><td>Male</td></tr><tr><td>Hispanic</td><td>Unanswered</td><td>Female</td></tr><tr><td>Non-Hispanic</td><td>American Indian and Alaska Native</td><td>Female</td></tr><tr><td>Unanswered</td><td>White</td><td>Male</td></tr><tr><td>Non-Hispanic</td><td>Unanswered</td><td>Female</td></tr><tr><td>Hispanic</td><td>Unanswered</td><td>Male</td></tr><tr><td>Hispanic</td><td>Native Hawaiian and Other Pacific Islander</td><td>Unanswered</td></tr><tr><td>Hispanic</td><td>Black or African American</td><td>Unanswered</td></tr><tr><td>Hispanic</td><td>White</td><td>Male</td></tr><tr><td>Non-Hispanic</td><td>White</td><td>Male</td></tr><tr><td>Unanswered</td><td>Native Hawaiian and Other Pacific Islander</td><td>Female</td></tr><tr><td>Hispanic</td><td>Asian</td><td>Unanswered</td></tr><tr><td>Non-Hispanic</td><td>Asian</td><td>Unanswered</td></tr><tr><td>Hispanic</td><td>American Indian and Alaska Native</td><td>Unanswered</td></tr><tr><td>Hispanic</td><td>White</td><td>Unanswered</td></tr><tr><td>Hispanic</td><td>Native Hawaiian and Other Pacific Islander</td><td>Male</td></tr><tr><td>Hispanic</td><td>White</td><td>Female</td></tr><tr><td>Hispanic</td><td>American Indian and Alaska Native</td><td>Female</td></tr><tr><td>Non-Hispanic</td><td>Black or African American</td><td>Male</td></tr><tr><td>Non-Hispanic</td><td>White</td><td>Female</td></tr><tr><td>Hispanic</td><td>American Indian and Alaska Native</td><td>Male</td></tr><tr><td>Unanswered</td><td>Asian</td><td>Male</td></tr><tr><td>Unanswered</td><td>American Indian and Alaska Native</td><td>Male</td></tr><tr><td>Non-Hispanic</td><td>Asian</td><td>Male</td></tr><tr><td>Hispanic</td><td>Asian</td><td>Male</td></tr><tr><td>Non-Hispanic</td><td>American Indian and Alaska Native</td><td>Male</td></tr><tr><td>Non-Hispanic</td><td>Native Hawaiian and Other Pacific Islander</td><td>Unanswered</td></tr><tr><td>Non-Hispanic</td><td>Unanswered</td><td>Male</td></tr><tr><td>Non-Hispanic</td><td>Black or African American</td><td>Unanswered</td></tr><tr><td>Unanswered</td><td>Black or African American</td><td>Female</td></tr><tr><td>Unanswered</td><td>Black or African American</td><td>Male</td></tr><tr><td>Non-Hispanic</td><td>Native Hawaiian and Other Pacific Islander</td><td>Female</td></tr><tr><td>Non-Hispanic</td><td>White</td><td>Unanswered</td></tr><tr><td>Unanswered</td><td>White</td><td>Female</td></tr><tr><td>Hispanic</td><td>Black or African American</td><td>Female</td></tr><tr><td>Non-Hispanic</td><td>American Indian and Alaska Native</td><td>Unanswered</td></tr><tr><td>Unanswered</td><td>Native Hawaiian and Other Pacific Islander</td><td>Male</td></tr><tr><td>Hispanic</td><td>Native Hawaiian and Other Pacific Islander</td><td>Female</td></tr><tr><td>Non-Hispanic</td><td>Black or African American</td><td>Female</td></tr></tbody></table></div>

# %%
saveToTable(Demographic_df, "dbo.DemographicInfo", change = "append")
